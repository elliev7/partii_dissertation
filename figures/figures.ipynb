ds_ip6_hh_cc = [3.47, 3.30, 3.30, 3.15, 3.30,
                3.10, 3.22, 3.31, 3.44, 3.30,
                3.41, 3.10, 3.28, 3.22, 3.25,
                3.32, 3.28, 3.42, 3.26, 3.47,
                3.03, 3.10, 3.22, 3.23, 3.08]
            
#Host 1 to Router
ds_ip6_hr = [2.02, 0.997, 1.08, 1.01, 0.926, 1.01, 0.990, 1.04, 0.976, 0.969, 0.988, 0.990, 1.05, 1.00, 1.02, 1.02, 1.03, 1.02, 0.992, 0.980, 
             0.988, 0.974, 1.06, 1.00, 1.08, 1.10, 1.08, 1.08, 1.11, 1.00, 1.01, 0.969, 1.03, 1.05, 1.02, 1.03, 0.961, 1.02, 0.992, 0.982, 
             1.02, 0.990, 1.11, 1.03, 0.986, 1.00, 0.978, 1.01, 0.986, 0.973, 0.989, 0.977, 1.05, 0.986, 0.979, 0.983, 0.964, 1.02, 1.07, 0.993, 
             1.13, 1.09, 1.11, 1.19, 1.15, 1.04, 0.997, 1.03, 1.00, 1.00, 1.08, 0.991, 1.05, 0.968, 1.05, 1.02, 0.979, 1.03, 1.01, 0.988, 
             0.995, 0.986, 1.05, 0.989, 1.06, 1.01, 0.970, 1.01, 0.981, 0.987, 1.02, 1.01, 1.04, 0.984, 1.03, 1.01, 1.13, 1.07, 1.10, 1.06]
ds_ip6_hr_cc = [2.02, 1.95, 1.87, 1.81, 1.78,
                1.74, 1.96, 1.79, 1.88, 1.78, 
                1.74, 1.78, 1.77, 1.90, 1.76,
                1.72, 1.74, 1.78, 1.78, 1.84,
                1.79, 1.81, 1.78, 1.89, 1.76]

# %%
r4_ip4_hh_mean = round(np.mean(r4_ip4_hh), 3)
r4_ip4_hh_std_dev = round(np.std(r4_ip4_hh), 3)
print("R4 IP4 HH Mean:", r4_ip4_hh_mean)
print("R4 IP4 HH Two Standard Deviations:", r4_ip4_hh_std_dev*2)

r6_ip6_hh_mean = round(np.mean(r6_ip6_hh), 3)
r6_ip6_hh_std_dev = round(np.std(r6_ip6_hh), 3)
print("R6 IP6 HH Mean:", r6_ip6_hh_mean)
print("R6 IP6 HH Two Standard Deviations:", r6_ip6_hh_std_dev*2)

ds_ip4_hh_mean = round(np.mean(ds_ip4_hh), 3)
ds_ip4_hh_std_dev = round(np.std(ds_ip4_hh), 3)
print("DS IP4 HH Mean:", ds_ip4_hh_mean)
print("DS IP4 HH Two Standard Deviations:", ds_ip4_hh_std_dev*2)

ds_ip6_hh_mean = round(np.mean(ds_ip6_hh), 3)
ds_ip6_hh_std_dev = round(np.std(ds_ip6_hh), 3)
print("DS IP6 HH Mean:", ds_ip6_hh_mean)
print("DS IP6 HH Two Standard Deviations:", ds_ip6_hh_std_dev*2)


r4_ip4_hr_mean = round(np.mean(r4_ip4_hr), 3)
r4_ip4_hr_std_dev = round(np.std(r4_ip4_hr), 3)
print("R4 IP4 HR Mean:", r4_ip4_hr_mean)
print("R4 IP4 HR Two Standard Deviations:", r4_ip4_hr_std_dev*2)

r6_ip6_hr_mean = round(np.mean(r6_ip6_hr), 3)
r6_ip6_hr_std_dev = round(np.std(r6_ip6_hr), 3)
print("R6 IP6 HR Mean:", r6_ip6_hr_mean)
print("R6 IP6 HR Two Standard Deviations:", r6_ip6_hr_std_dev*2)

ds_ip4_hr_mean = round(np.mean(ds_ip4_hr), 3)
ds_ip4_hr_std_dev = round(np.std(ds_ip4_hr), 3)
print("DS IP4 HR Mean:", ds_ip4_hr_mean)
print("DS IP4 HR Two Standard Deviations:", ds_ip4_hr_std_dev*2)

ds_ip6_hr_mean = round(np.mean(ds_ip6_hr), 3)
ds_ip6_hr_std_dev = round(np.std(ds_ip6_hr), 3)
print("DS IP6 HR Mean:", ds_ip6_hr_mean)
print("DS IP6 HR Two Standard Deviations:", ds_ip6_hr_std_dev*2)
# Out:
# R4 IP4 HH Mean: 1.49
# R4 IP4 HH Two Standard Deviations: 0.282
# R6 IP6 HH Mean: 1.568
# R6 IP6 HH Two Standard Deviations: 0.374
# DS IP4 HH Mean: 1.578
# DS IP4 HH Two Standard Deviations: 0.192
# DS IP6 HH Mean: 1.62
# DS IP6 HH Two Standard Deviations: 0.388
# R4 IP4 HR Mean: 0.906
# R4 IP4 HR Two Standard Deviations: 0.328
# R6 IP6 HR Mean: 0.964
# R6 IP6 HR Two Standard Deviations: 0.208
# DS IP4 HR Mean: 1.032
# DS IP4 HR Two Standard Deviations: 0.228
# DS IP6 HR Mean: 1.031
# DS IP6 HR Two Standard Deviations: 0.22

# %%
r4_ip4_hh_cc_mean = round(np.mean(r4_ip4_hh_cc), 3)
r4_ip4_hh_cc_std_dev = round(np.std(r4_ip4_hh_cc), 3)
print("R4 IP4 HH CC Mean:", r4_ip4_hh_cc_mean)
print("R4 IP4 HH CC Two Standard Deviations:", r4_ip4_hh_cc_std_dev*2)

r6_ip6_hh_cc_mean = round(np.mean(r6_ip6_hh_cc), 3)
r6_ip6_hh_cc_std_dev = round(np.std(r6_ip6_hh_cc), 3)
print("R6 IP6 HH CC Mean:", r6_ip6_hh_cc_mean)
print("R6 IP6 HH CC Two Standard Deviations:", r6_ip6_hh_cc_std_dev*2)

ds_ip4_hh_cc_mean = round(np.mean(ds_ip4_hh_cc), 3)
ds_ip4_hh_cc_std_dev = round(np.std(ds_ip4_hh_cc), 3)
print("DS IP4 HH CC Mean:", ds_ip4_hh_cc_mean)
print("DS IP4 HH CC Two Standard Deviations:", ds_ip4_hh_cc_std_dev*2)

ds_ip6_hh_cc_mean = round(np.mean(ds_ip6_hh_cc), 3)
ds_ip6_hh_cc_std_dev = round(np.std(ds_ip6_hh_cc), 3)
print("DS IP6 HH CC Mean:", ds_ip6_hh_cc_mean)
print("DS IP6 HH CC Two Standard Deviations:", ds_ip6_hh_cc_std_dev*2)

r4_ip4_hr_cc_mean = round(np.mean(r4_ip4_hr_cc), 3)
r4_ip4_hr_cc_std_dev = round(np.std(r4_ip4_hr_cc), 3)
print("R4 IP4 HR CC Mean:", r4_ip4_hr_cc_mean)
print("R4 IP4 HR CC Two Standard Deviations:", r4_ip4_hr_cc_std_dev*2)

r6_ip6_hr_cc_mean = round(np.mean(r6_ip6_hr_cc), 3)
r6_ip6_hr_cc_std_dev = round(np.std(r6_ip6_hr_cc), 3)
print("R6 IP6 HR CC Mean:", r6_ip6_hr_cc_mean)
print("R6 IP6 HR CC Two Standard Deviations:", r6_ip6_hr_cc_std_dev*2)

ds_ip4_hr_cc_mean = round(np.mean(ds_ip4_hr_cc), 3)
ds_ip4_hr_cc_std_dev = round(np.std(ds_ip4_hr_cc), 3)
print("DS IP4 HR CC Mean:", ds_ip4_hr_cc_mean)
print("DS IP4 HR CC Two Standard Deviations:", ds_ip4_hr_cc_std_dev*2)

ds_ip6_hr_cc_mean = round(np.mean(ds_ip6_hr_cc), 3)
ds_ip6_hr_cc_std_dev = round(np.std(ds_ip6_hr_cc), 3)
print("DS IP6 HR CC Mean:", ds_ip6_hr_cc_mean)
print("DS IP6 HR CC Two Standard Deviations:", ds_ip6_hr_cc_std_dev*2)
# Out:
# R4 IP4 HH CC Mean: 2.77
# R4 IP4 HH CC Two Standard Deviations: 0.202
# R6 IP6 HH CC Mean: 3.235
# R6 IP6 HH CC Two Standard Deviations: 0.19
# DS IP4 HH CC Mean: 2.864
# DS IP4 HH CC Two Standard Deviations: 0.28
# DS IP6 HH CC Mean: 3.262
# DS IP6 HH CC Two Standard Deviations: 0.24
# R4 IP4 HR CC Mean: 1.596
# R4 IP4 HR CC Two Standard Deviations: 0.244
# R6 IP6 HR CC Mean: 1.746
# R6 IP6 HR CC Two Standard Deviations: 0.146
# DS IP4 HR CC Mean: 1.748
# DS IP4 HR CC Two Standard Deviations: 0.32
# DS IP6 HR CC Mean: 1.817
# DS IP6 HR CC Two Standard Deviations: 0.152

# %%
r4_ip4_hh_sorted = np.sort(r4_ip4_hh)
r6_ip6_hh_sorted = np.sort(r6_ip6_hh)
ds_ip4_hh_sorted = np.sort(ds_ip4_hh)
ds_ip6_hh_sorted = np.sort(ds_ip6_hh)

r4_ip4_hh_cdf = np.arange(len(r4_ip4_hh_sorted)) / float(len(r4_ip4_hh_sorted))
r6_ip6_hh_cdf = np.arange(len(r6_ip6_hh_sorted)) / float(len(r6_ip6_hh_sorted))
ds_ip4_hh_cdf = np.arange(len(ds_ip4_hh_sorted)) / float(len(ds_ip4_hh_sorted))
ds_ip6_hh_cdf = np.arange(len(ds_ip6_hh_sorted)) / float(len(ds_ip6_hh_sorted))

r4_ip4_hr_sorted = np.sort(r4_ip4_hr)
r6_ip6_hr_sorted = np.sort(r6_ip6_hr)
ds_ip4_hr_sorted = np.sort(ds_ip4_hr)
ds_ip6_hr_sorted = np.sort(ds_ip6_hr)

r4_ip4_hr_cdf = np.arange(len(r4_ip4_hr_sorted)) / float(len(r4_ip4_hr_sorted))
r6_ip6_hr_cdf = np.arange(len(r6_ip6_hr_sorted)) / float(len(r6_ip6_hr_sorted))
ds_ip4_hr_cdf = np.arange(len(ds_ip4_hr_sorted)) / float(len(ds_ip4_hr_sorted))
ds_ip6_hr_cdf = np.arange(len(ds_ip6_hr_sorted)) / float(len(ds_ip6_hr_sorted))

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

axs[0].plot(r4_ip4_hh_sorted, r4_ip4_hh_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[0].plot(r6_ip6_hh_sorted, r6_ip6_hh_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[0].plot(ds_ip4_hh_sorted, ds_ip4_hh_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[0].plot(ds_ip6_hh_sorted, ds_ip6_hh_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[0].grid(True)
axs[0].set_title('Host-to-Host ping RTT (ms)')
axs[0].set_xlabel('Time (ms)')
axs[0].set_ylabel('Cumulative Probability')
axs[0].legend()

axs[1].plot(r4_ip4_hr_sorted, r4_ip4_hr_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[1].plot(r6_ip6_hr_sorted, r6_ip6_hr_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[1].plot(ds_ip4_hr_sorted, ds_ip4_hr_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[1].plot(ds_ip6_hr_sorted, ds_ip6_hr_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[1].grid(True)
axs[1].set_title('Host-to-Router ping RTT (ms)')
axs[1].set_xlabel('Time (ms)')
axs[1].set_ylabel('Cumulative Probability')
axs[1].legend()

plt.savefig('Ping_all.png')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

axs[0].plot(r4_ip4_hh_sorted[:99], r4_ip4_hh_cdf[:99], label='IPv4 Router', color='green', linestyle='dotted')
axs[0].plot(r6_ip6_hh_sorted[:99], r6_ip6_hh_cdf[:99], label='IPv6 Router', color='blue', linestyle='dashed')
axs[0].plot(ds_ip4_hh_sorted[:99], ds_ip4_hh_cdf[:99], label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[0].plot(ds_ip6_hh_sorted[:99], ds_ip6_hh_cdf[:99], label='Dual-stack IPv6', color='red', linestyle='solid')
axs[0].grid(True)
axs[0].set_title('Warm Cache Host-to-Host Ping RTT (ms)')
axs[0].set_xlabel('Time (ms)')
axs[0].set_ylabel('Cumulative Probability')
axs[0].legend()

axs[1].plot(r4_ip4_hr_sorted[:99], r4_ip4_hr_cdf[:99], label='IPv4 Router', color='green',linestyle='dotted')
axs[1].plot(r6_ip6_hr_sorted[:99], r6_ip6_hr_cdf[:99], label='IPv6 Router', color='blue', linestyle='dashed')
axs[1].plot(ds_ip4_hr_sorted[:99], ds_ip4_hr_cdf[:99], label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[1].plot(ds_ip6_hr_sorted[:99], ds_ip6_hr_cdf[:99], label='Dual-stack IPv6', color='red', linestyle='solid')
axs[1].grid(True)
axs[1].set_title('Warm Cache Host-to-Router Ping RTT (ms)')
axs[1].set_xlabel('Time (ms)')
axs[1].set_ylabel('Cumulative Probability')
axs[1].legend()

plt.savefig('Ping_WC.png')
plt.show()

# %%
r4_ip4_hh_cc_sorted = np.sort(r4_ip4_hh_cc)
r6_ip6_hh_cc_sorted = np.sort(r6_ip6_hh_cc)
ds_ip4_hh_cc_sorted = np.sort(ds_ip4_hh_cc)
ds_ip6_hh_cc_sorted = np.sort(ds_ip6_hh_cc)

r4_ip4_hh_cc_cdf = np.arange(len(r4_ip4_hh_cc_sorted)) / float(len(r4_ip4_hh_cc_sorted))
r6_ip6_hh_cc_cdf = np.arange(len(r6_ip6_hh_cc_sorted)) / float(len(r6_ip6_hh_cc_sorted))
ds_ip4_hh_cc_cdf = np.arange(len(ds_ip4_hh_cc_sorted)) / float(len(ds_ip4_hh_cc_sorted))
ds_ip6_hh_cc_cdf = np.arange(len(ds_ip6_hh_cc_sorted)) / float(len(ds_ip6_hh_cc_sorted))

r4_ip4_hr_cc_sorted = np.sort(r4_ip4_hr_cc)
r6_ip6_hr_cc_sorted = np.sort(r6_ip6_hr_cc)
ds_ip4_hr_cc_sorted = np.sort(ds_ip4_hr_cc)
ds_ip6_hr_cc_sorted = np.sort(ds_ip6_hr_cc)

r4_ip4_hr_cc_cdf = np.arange(len(r4_ip4_hr_cc_sorted)) / float(len(r4_ip4_hr_cc_sorted))
r6_ip6_hr_cc_cdf = np.arange(len(r6_ip6_hr_cc_sorted)) / float(len(r6_ip6_hr_cc_sorted))
ds_ip4_hr_cc_cdf = np.arange(len(ds_ip4_hr_cc_sorted)) / float(len(ds_ip4_hr_cc_sorted))
ds_ip6_hr_cc_cdf = np.arange(len(ds_ip6_hr_cc_sorted)) / float(len(ds_ip6_hr_cc_sorted))

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

axs[0].plot(r4_ip4_hh_cc_sorted, r4_ip4_hh_cc_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[0].plot(r6_ip6_hh_cc_sorted, r6_ip6_hh_cc_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[0].plot(ds_ip4_hh_cc_sorted, ds_ip4_hh_cc_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[0].plot(ds_ip6_hh_cc_sorted, ds_ip6_hh_cc_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[0].grid(True)
axs[0].set_title('Cold Cache Host-to-Host Ping RTT (ms)')
axs[0].set_xlabel('Time (ms)')
axs[0].set_ylabel('Cumulative Probability')
axs[0].legend()

axs[1].plot(r4_ip4_hr_cc_sorted, r4_ip4_hr_cc_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[1].plot(r6_ip6_hr_cc_sorted, r6_ip6_hr_cc_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[1].plot(ds_ip4_hr_cc_sorted, ds_ip4_hr_cc_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[1].plot(ds_ip6_hr_cc_sorted, ds_ip6_hr_cc_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[1].grid(True)
axs[1].set_title('Cold Cache Host-to-Router Ping RTT (ms)')
axs[1].set_xlabel('Time (ms)')
axs[1].set_ylabel('Cumulative Probability')
axs[1].legend()

plt.savefig('Ping_CC.png')
plt.show()
