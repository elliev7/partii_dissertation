# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
#collecting data (in ms)
#pinging warm cache for 250 samples
#pinging cold cache for 25 samples

# Router4 IPv4 
#Host 1 to Host 2
r4_ip4_hh = [1.60, 1.51, 1.48, 1.53, 1.60, 1.56, 1.53, 1.54, 1.51, 1.44, 1.46, 1.55, 1.50, 1.48, 1.43, 1.43, 1.43, 1.46, 1.49, 1.44, 1.42, 1.43, 1.47, 1.42, 1.45, 
             1.41, 1.38, 1.46, 1.44, 1.47, 1.47, 1.40, 1.45, 1.43, 1.50, 1.45, 1.43, 1.53, 1.43, 1.55, 1.52, 1.51, 1.56, 1.52, 1.53, 1.47, 1.40, 1.45, 1.43, 1.47, 
             1.43, 1.40, 1.51, 1.48, 1.42, 1.43, 1.40, 1.46, 1.47, 1.43, 1.44, 1.40, 1.48, 1.44, 1.50, 1.48, 1.40, 1.45, 1.41, 1.53, 1.48, 1.40, 1.47, 1.44, 1.43, 
             1.49, 1.53, 1.50, 1.49, 1.51, 1.52, 1.42, 1.48, 1.44, 1.44, 1.55, 1.42, 1.47, 1.50, 1.43, 1.49, 1.42, 1.46, 1.46, 1.40, 1.46, 1.42, 1.46, 1.44, 1.43, 
             1.49, 1.45, 1.47, 1.48, 1.42, 1.44, 1.50, 1.48, 1.42, 1.41, 1.45, 1.42, 1.52, 1.50, 1.52, 1.50, 1.56, 1.49, 1.44, 1.48, 1.44, 1.42, 1.49, 1.43, 1.51, 
             1.47, 1.43, 1.53, 1.43, 1.43, 1.42, 1.42, 1.46, 1.42, 1.46, 1.45, 1.45, 1.45, 1.41, 1.42, 1.45, 1.45, 1.47, 1.44, 1.44, 1.43, 1.44, 1.48, 1.50, 1.58, 
             1.54, 1.52, 1.57, 1.52, 1.45, 1.48, 1.42, 1.49, 1.45, 1.44, 1.59, 1.47, 1.53, 1.46, 1.47, 1.48, 1.49, 1.49, 1.49, 1.51, 1.45, 1.42, 1.50, 1.48, 1.47, 
             1.45, 1.45, 1.46, 1.45, 1.51, 1.50, 1.47, 1.53, 1.46, 1.90, 1.60, 1.55, 1.57, 1.56, 1.54, 1.56, 1.47, 1.51, 1.46, 1.99, 1.53, 1.44, 1.46, 1.45, 1.43, 
             1.44, 1.53, 1.47, 1.42, 1.46, 1.44, 1.44, 1.47, 1.43, 1.45, 1.52, 1.28, 1.52, 1.49, 1.45, 1.52, 1.44, 1.47, 1.43, 1.43, 1.50, 1.52, 1.31, 1.54, 1.56, 
             1.55, 1.44, 1.50, 1.43, 1.42, 1.43, 1.45, 1.49, 1.43, 1.47, 1.43, 1.44, 1.48, 1.42, 1.44, 1.44, 1.39, 1.48, 1.49, 1.51, 1.48, 1.43, 1.47, 1.51, 1.43]
r4_ip4_hh_cc = [2.77, 2.78, 2.56, 2.77, 2.80, 2.89, 2.67, 2.84, 2.54, 2.88, 2.63, 2.74, 2.62, 2.74, 2.88,
                2.75, 2.78, 2.80, 2.94, 2.69, 2.83, 2.82, 2.88, 2.81, 2.83]

#Host 1 to Router
r4_ip4_hr = [0.958, 0.899, 0.913, 0.916, 0.896, 1.04, 0.984, 0.978, 1.03, 0.979, 0.956, 0.913, 1.00, 0.952, 0.981, 0.913, 0.989, 0.899, 0.938, 0.903, 1.05, 0.960, 
             0.902, 0.897, 0.991, 1.05, 0.926, 0.894, 0.966, 0.899, 0.944, 0.962, 0.988, 0.945, 0.918, 0.931, 0.946, 0.911, 0.909, 0.925, 1.00, 1.03, 1.07, 1.09, 
             1.05, 0.958, 1.05, 0.989, 1.05, 0.942, 0.996, 0.993, 1.06, 0.919, 0.912, 1.08, 1.00, 1.03, 0.941, 0.913, 1.02, 0.814, 0.981, 0.926, 0.939, 0.918, 
             0.963, 0.911, 1.03, 0.968, 0.956, 0.919, 0.983, 0.893, 0.947, 0.961, 0.963, 1.15, 1.07, 0.951, 1.08, 1.03, 0.976, 0.927, 1.03, 0.935, 0.911, 0.994, 
             1.06, 0.968, 0.893, 0.946, 0.988, 0.971, 1.02, 0.969, 0.972, 0.904, 0.968, 0.928, 1.02, 0.882, 0.898, 0.937, 0.974, 0.948, 0.913, 0.978, 0.979, 0.962, 
             0.660, 0.925, 1.00, 0.919, 0.990, 1.02, 1.08, 1.02, 1.01, 0.986, 1.06, 0.951, 0.929, 0.955, 0.838, 0.904, 0.875, 0.861, 0.922, 0.983, 0.929, 0.909, 
             0.898, 0.972, 0.924, 0.918, 1.03, 1.00, 0.925, 1.03, 1.08, 0.907, 0.979, 0.983, 1.05, 0.941, 1.00, 0.973, 1.07, 0.956, 0.983, 1.07, 1.19, 1.23, 1.03, 
             0.972, 1.05, 0.937, 0.927, 0.974, 1.03, 0.957, 0.992, 0.939, 1.00, 0.938, 0.885, 0.945, 1.01, 1.01, 0.969, 0.934, 1.04, 0.971, 0.934, 0.953, 1.00, 
             0.912, 0.933, 0.973, 1.15, 1.04, 1.04, 0.968, 1.05, 0.935, 1.02, 0.929, 1.06, 1.10, 0.865, 0.923, 0.956, 0.946, 0.904, 0.945, 1.03, 0.961, 0.911, 
             0.962, 1.00, 0.904, 0.954, 0.963, 0.991, 0.871, 0.909, 1.11, 0.955, 0.938, 0.925, 0.954, 0.993, 0.908, 0.979, 0.951, 1.07, 0.926, 0.932, 1.00, 1.03, 
             0.891, 1.07, 1.03, 1.15, 1.07, 1.07, 1.00, 0.976, 0.997, 0.912, 0.989, 0.987, 0.932, 0.917, 1.04, 0.951, 0.977, 0.956, 0.952, 0.978, 0.948, 0.982, 
             0.964, 0.977, 0.885, 0.917, 0.951, 1.05, 0.971]
r4_ip4_hr_cc = [1.91, 1.62, 1.70, 1.72, 1.66,
                1.64, 1.72, 1.61, 1.67, 1.44,
                1.50, 1.54, 1.53, 1.40, 1.82,
                1.55, 1.54, 1.34, 1.57, 1.53,
                1.62, 1.64, 1.53, 1.56, 1.54]

#Router6 IPv6
#Host 1 to Host 2
r6_ip6_hh = [1.60, 1.56, 1.53, 1.47, 1.52, 1.54, 1.45, 1.50, 1.47, 1.36, 1.46, 1.57, 1.53, 1.33, 1.53, 1.47, 1.46, 1.56, 1.45, 1.50, 1.46, 1.53, 1.56, 1.49, 1.52, 
             1.51, 1.48, 1.59, 1.55, 1.58, 1.61, 1.67, 1.55, 1.50, 1.58, 1.51, 1.50, 1.54, 1.58, 1.53, 1.50, 1.50, 1.57, 1.54, 1.56, 1.54, 1.56, 1.53, 1.59, 1.55, 
             1.53, 1.50, 1.66, 1.52, 1.62, 1.50, 1.49, 1.52, 1.55, 1.59, 1.51, 1.57, 1.54, 1.62, 1.63, 1.63, 1.58, 1.58, 1.64, 1.57, 1.53, 1.50, 1.64, 1.41, 1.57, 
             1.51, 1.54, 1.51, 1.49, 1.53, 1.50, 1.50, 1.59, 1.48, 1.60, 1.58, 1.65, 1.52, 1.50, 1.52, 1.50, 1.49, 1.54, 1.51, 1.57, 1.54, 1.53, 1.51, 1.59, 1.52, 
             1.64, 1.64, 1.68, 1.61, 1.68, 1.58, 1.54, 1.55, 1.49, 1.54, 1.59, 1.57, 1.66, 1.52, 1.56, 1.53, 1.51, 1.55, 1.50, 1.58, 1.54, 1.61, 1.52, 1.56, 1.55, 
             1.57, 1.51, 1.55, 1.47, 1.65, 1.48, 1.54, 1.61, 1.56, 1.57, 1.52, 1.64, 1.68, 1.59, 1.60, 1.44, 1.55, 1.52, 1.49, 1.64, 1.50, 1.59, 1.51, 1.56, 1.56, 
             1.54, 1.62, 1.56, 1.51, 1.62, 1.54, 1.55, 1.54, 1.60, 1.52, 1.55, 1.49, 1.63, 1.61, 1.72, 1.62, 1.50, 1.58, 1.54, 1.58, 1.54, 1.69, 1.71, 1.69, 1.63, 
             1.91, 1.64, 1.63, 1.53, 1.61, 1.54, 1.52, 1.51, 1.53, 1.55, 1.49, 1.49, 1.55, 1.60, 1.63, 1.49, 1.61, 1.51, 1.56, 1.59, 1.52, 1.50, 1.53, 1.47, 1.59, 
             1.43, 1.51, 1.50, 1.57, 1.38, 1.50, 1.51, 1.59, 1.48, 1.63, 1.61, 1.63, 1.64, 1.62, 1.59, 1.54, 1.58, 1.59, 1.63, 1.54, 1.57, 1.52, 1.54, 1.58, 1.62, 
             1.53, 1.61, 1.52, 1.59, 1.53, 1.55, 1.65, 1.59, 1.50, 1.67, 1.55, 1.52, 1.53, 1.55, 1.53, 1.54, 1.55, 1.54, 1.55, 1.56, 1.61, 1.64, 1.65, 1.63, 1.68]
r6_ip6_hh_cc = [3.34, 3.06, 3.14, 3.29, 3.25, 
                3.18, 3.17, 3.28, 3.08, 3.28,
                3.28, 3.32, 3.26, 3.13, 3.23,
                3.21, 3.32, 3.26, 3.35, 3.02,
                3.26, 3.41, 3.17, 3.34, 3.24]

#Host 1 to Router
r6_ip6_hr = [1.07, 1.01, 0.966, 1.02, 1.06, 1.11, 1.09, 1.10, 1.01, 0.979, 1.01, 1.04, 0.956, 0.957, 1.01, 0.949, 0.940, 1.01, 0.951, 0.994, 0.968, 0.938, 0.946, 
             0.740, 0.979, 0.944, 0.956, 0.957, 0.938, 0.940, 0.782, 0.809, 1.02, 0.931, 0.997, 0.935, 0.933, 0.939, 1.01, 0.948, 0.988, 0.995, 1.00, 1.01, 1.01, 
             0.981, 0.943, 0.938, 0.936, 0.975, 0.959, 0.924, 0.966, 0.940, 1.05, 0.969, 0.936, 0.931, 0.914, 0.932, 0.926, 0.918, 0.954, 0.918, 1.01, 0.938, 
             0.947, 0.941, 0.930, 0.950, 0.959, 0.934, 0.946, 0.948, 0.991, 1.02, 1.01, 1.00, 1.01, 0.999, 1.03, 0.955, 0.948, 0.952, 0.992, 0.967, 0.967, 0.966, 
             0.966, 0.960, 0.933, 1.02, 0.945, 0.973, 0.981, 0.934, 0.792, 0.989, 0.931, 0.975, 0.967, 0.929, 0.940, 0.943, 0.980, 0.938, 0.978, 0.951, 0.932, 
             0.968, 0.963, 0.938, 1.03, 1.05, 1.08, 1.08, 1.09, 1.08, 0.941, 0.969, 0.945, 0.946, 0.972, 0.954, 0.988, 0.934, 0.927, 0.990, 0.915, 0.949, 0.972, 
             0.923, 0.939, 1.00, 0.996, 0.936, 0.923, 0.938, 0.922, 0.979, 0.935, 0.948, 0.966, 0.933, 0.975, 0.945, 0.928, 0.958, 0.918, 1.00, 0.999, 1.00, 1.03, 
             1.01, 0.988, 0.942, 0.940, 0.940, 0.948, 1.04, 0.789, 0.934, 0.942, 0.952, 0.984, 0.928, 0.960, 0.943, 0.917, 0.966, 0.957, 0.929, 0.941, 0.924, 0.990, 
             0.943, 0.924, 0.945, 0.919, 0.975, 1.06, 0.940, 0.944, 0.995, 0.980, 1.01, 0.996, 1.00, 1.00, 1.00, 0.966, 0.940, 0.937, 0.936, 0.996, 0.967, 0.936, 
             0.943, 0.968, 0.970, 0.959, 1.03, 0.947, 0.932, 0.980, 0.945, 0.928, 0.945, 0.938, 0.947, 0.967, 0.938, 0.936, 0.922, 0.978, 0.945, 0.930, 1.02, 0.964, 
             0.973, 0.937, 1.09, 1.01, 1.03, 1.02, 1.01, 0.997, 0.950, 0.961, 0.951, 0.944, 0.955, 0.977, 0.930, 0.984, 0.971, 0.927, 0.940, 1.01, 0.956, 0.939, 
             0.930, 0.940, 0.916, 0.973, 0.929, 0.976, 0.942, 0.942, 0.960]
r6_ip6_hr_cc = [1.86, 1.76, 1.87, 1.71, 1.66,
                1.69, 1.72, 1.69, 1.75, 1.69,
                1.72, 1.68, 1.72, 1.76, 1.89,
                1.71, 1.70, 1.75, 1.71, 1.71, 
                1.80, 1.69, 1.75, 1.71, 1.96]

#DualStack IPv4
#Host 1 to Host 2
ds_ip4_hh = [1.55, 1.61, 1.51, 1.51, 1.51, 1.54, 1.51, 1.47, 1.52, 1.47, 1.64, 1.55, 1.50, 1.48, 1.52, 1.52, 1.56, 1.48, 1.53, 1.47, 1.55, 1.53, 1.61, 1.58, 1.59, 
             1.59, 1.57, 1.52, 1.51, 1.54, 1.54, 1.52, 1.40, 1.50, 1.55, 1.48, 1.49, 1.52, 1.49, 1.56, 1.48, 1.48, 1.48, 1.57, 1.53, 1.46, 1.49, 1.49, 1.48, 1.56, 
             1.53, 1.48, 1.48, 1.47, 1.52, 1.47, 1.55, 1.54, 1.58, 1.75, 1.64, 1.65, 1.61, 1.54, 1.57, 1.47, 1.50, 1.49, 1.50, 1.62, 1.50, 1.50, 1.47, 1.48, 1.61, 
             1.49, 1.53, 1.48, 1.46, 1.58, 1.56, 1.50, 1.46, 1.50, 1.57, 1.49, 1.51, 1.47, 1.48, 1.63, 1.49, 1.54, 1.51, 1.50, 1.70, 1.58, 1.65, 1.58, 1.59, 1.58, 
             1.37, 1.51, 1.47, 1.50, 1.55, 1.49, 1.49, 1.49, 1.54, 1.62, 1.51, 1.49, 1.48, 1.51, 1.52, 1.48, 1.48, 1.56, 1.48, 1.62, 1.60, 1.55, 1.47, 1.49, 1.55, 
             1.50, 1.48, 1.49, 1.47, 1.58, 1.51, 1.59, 1.56, 1.61, 1.57, 1.57, 1.56, 1.51, 1.55, 1.53, 1.52, 1.49, 1.47, 1.50, 1.53, 1.50, 1.69, 1.60, 1.45, 1.66, 
             1.59, 1.50, 1.55, 1.46, 1.51, 1.52, 1.50, 1.68, 1.48, 1.55, 1.36, 1.48, 1.55, 1.23, 1.50, 1.56, 1.48, 1.59, 1.56, 1.56, 1.56, 1.58, 1.59, 1.49, 1.51, 
             1.51, 1.48, 1.52, 1.49, 1.52, 1.60, 1.50, 1.55, 1.46, 1.52, 1.50, 1.53, 1.52, 1.46, 1.54, 1.55, 1.48, 1.48, 1.46, 1.50, 1.50, 1.49, 1.52, 1.50, 1.54, 
             1.48, 1.52, 1.54, 1.59, 1.63, 1.86, 1.58, 1.64, 1.63, 1.63, 1.59, 1.55, 1.55, 1.58, 1.58, 1.53, 1.55, 1.56, 1.62, 1.57, 1.54, 1.53, 1.55, 1.54, 1.56, 
             1.52, 1.54, 1.55, 1.48, 1.56, 1.49, 1.52, 1.51, 1.48, 1.59, 1.51, 1.49, 1.49, 1.49, 1.55, 1.64, 1.60, 1.57, 1.57, 1.55, 1.51, 1.51, 1.56, 1.47, 1.53]
ds_ip4_hh_cc = [2.32, 2.89, 3.02, 2.98, 2.95,
                2.85, 2.76, 3.01, 2.87, 2.96,
                2.92, 2.97, 3.01, 2.95, 2.79, 
                2.95, 2.82, 2.86, 2.89, 2.80, 
                2.83, 2.66, 2.82, 2.85, 2.86]

#Host 1 to Router
ds_ip4_hr = [1.15, 0.945, 0.941, 0.959, 1.02, 0.988, 1.06, 0.945, 1.02, 0.955, 0.986, 0.953, 1.02, 0.962, 0.951, 0.963, 1.03, 1.05, 1.02, 1.03, 1.06, 0.969, 0.957, 
             0.979, 1.02, 0.965, 0.978, 1.02, 1.04, 0.976, 0.963, 0.943, 0.996, 0.960, 0.941, 0.908, 0.998, 0.950, 0.954, 0.929, 1.01, 0.968, 0.952, 1.02, 1.01, 
             1.00, 0.969, 0.945, 1.01, 0.926, 0.960, 0.970, 1.03, 1.03, 1.05, 1.02, 1.06, 0.952, 0.982, 0.976, 1.01, 0.933, 0.999, 0.946, 1.06, 1.00, 0.963, 0.949, 
             1.03, 0.980, 0.974, 0.943, 1.01, 0.951, 0.937, 0.980, 1.00, 0.980, 0.978, 0.991, 1.12, 0.940, 0.974, 0.984, 1.02, 1.01, 0.996, 0.957, 1.20, 0.810, 1.24, 
             1.13, 1.29, 0.997, 0.975, 1.05, 1.18, 0.937, 0.968, 0.973, 0.999, 0.845, 0.949, 0.914, 0.960, 1.02, 0.960, 0.950, 1.02, 0.936, 0.994, 0.938, 1.01, 
             0.982, 0.983, 0.980, 1.02, 0.944, 0.975, 1.00, 1.02, 0.964, 0.989, 0.949, 1.01, 1.02, 1.02, 1.01, 1.08, 1.14, 0.976, 0.956, 1.04, 0.964, 0.956, 0.990, 
             1.03, 0.940, 1.02, 0.976, 1.02, 0.931, 0.951, 0.953, 1.01, 1.04, 0.977, 0.944, 1.02, 0.949, 0.978, 0.950, 1.05, 0.960, 0.961, 1.00, 1.01, 0.949, 0.984, 
             1.01, 1.02, 1.07, 1.02, 1.01, 1.10, 1.02, 0.966, 0.950, 0.992, 0.958, 0.971, 0.984, 0.980, 0.957, 0.953, 1.01, 1.02, 0.944, 0.963, 0.941, 1.07, 0.944, 
             1.02, 0.949, 0.987, 0.982, 0.964, 0.968, 1.01, 0.954, 0.971, 0.953, 1.01, 0.974, 0.957, 1.00, 1.06, 1.04, 1.02, 1.03, 1.16, 1.04, 1.07, 1.00, 1.02, 
             1.00, 0.952, 0.987, 1.02, 0.962, 0.990, 0.988, 1.00, 0.964, 0.990, 1.01, 0.998, 0.989, 0.957, 0.950, 1.02, 0.982, 0.953, 0.967, 1.00, 1.06, 0.957, 
             0.963, 0.999, 0.948, 0.952, 0.948, 0.997, 0.995, 1.05, 1.02, 1.11, 1.03, 1.09, 0.999, 1.05, 0.935, 0.946, 0.961, 1.09, 0.995, 0.956, 0.971, 1.03, 0.957]
ds_ip4_hr_cc = [1.95, 1.99, 1.77, 1.58, 1.39, 
                1.97, 1.66, 1.84, 1.95, 1.82,
                1.81, 1.78, 1.46, 1.54, 1.58,
                1.65, 1.58, 1.72, 1.69, 1.81,
                1.80, 1.85, 1.68, 1.91, 1.91]

#DualStack IPv6
#Host 1 to Host 2
ds_ip6_hh = [1.61, 1.51, 1.53, 1.52, 1.55, 1.61, 1.50, 1.64, 1.50, 1.50, 1.57, 1.53, 1.56, 1.54, 1.49, 1.55, 1.50, 1.58, 1.55, 1.59, 1.58, 1.64, 1.66, 1.63, 1.61, 
             1.69, 1.58, 1.55, 1.64, 1.53, 1.56, 1.60, 1.54, 1.61, 1.53, 1.67, 1.55, 1.60, 1.69, 1.57, 1.58, 1.58, 1.57, 1.59, 1.56, 1.59, 1.54, 1.42, 1.53, 1.53, 
             1.62, 1.56, 1.59, 1.62, 1.60, 1.75, 1.59, 1.67, 1.63, 1.71, 1.68, 1.69, 1.57, 1.61, 1.62, 1.66, 1.54, 1.59, 1.56, 1.56, 1.71, 1.53, 1.71, 1.62, 1.53, 
             1.66, 1.53, 1.60, 1.63, 1.60, 1.57, 1.55, 1.53, 1.58, 1.57, 1.64, 1.64, 1.58, 1.60, 1.58, 1.60, 1.54, 1.62, 1.78, 1.73, 1.76, 1.66, 1.66, 1.69, 1.60, 
             1.66, 1.58, 1.61, 1.62, 1.63, 1.63, 1.61, 1.61, 1.57, 1.54, 1.55, 1.52, 1.58, 1.55, 1.63, 1.67, 1.64, 1.52, 1.45, 1.61, 1.56, 1.56, 1.66, 1.56, 1.36, 
             1.63, 1.62, 1.59, 1.78, 1.54, 1.67, 1.61, 1.66, 1.63, 1.67, 1.64, 1.61, 1.62, 1.62, 1.62, 1.65, 1.53, 1.55, 1.52, 1.60, 1.56, 1.54, 1.59, 1.53, 1.60, 
             1.57, 1.55, 1.58, 1.65, 1.46, 1.68, 1.54, 1.52, 1.67, 1.59, 1.61, 1.62, 1.58, 1.55, 1.62, 1.70, 1.70, 1.64, 1.71, 1.78, 1.75, 1.67, 1.59, 1.59, 1.73, 
             2.01, 1.97, 1.67, 1.63, 1.64, 1.58, 1.64, 1.45, 1.58, 1.55, 1.54, 1.72, 1.53, 1.63, 1.46, 1.56, 1.51, 1.54, 1.54, 1.51, 1.71, 1.59, 1.50, 1.57, 1.50, 
             1.55, 1.53, 1.59, 1.64, 1.70, 1.58, 1.63, 1.68, 1.61, 1.60, 1.57, 1.57, 1.62, 1.55, 1.54, 1.57, 1.73, 1.57, 1.58, 1.52, 1.56, 1.55, 1.60, 1.56, 1.56, 
             1.60, 1.63, 1.58, 1.55, 1.60, 1.62, 1.65, 1.60, 1.69, 1.68, 1.66, 1.62, 1.67, 1.69, 1.70, 1.67, 1.64, 1.68, 1.73, 1.66, 1.72, 1.47, 1.57, 1.52, 1.59]
ds_ip6_hh_cc = [3.47, 3.30, 3.30, 3.15, 3.30,
                3.10, 3.22, 3.31, 3.44, 3.30,
                3.41, 3.10, 3.28, 3.22, 3.25,
                3.32, 3.28, 3.42, 3.26, 3.47,
                3.03, 3.10, 3.22, 3.23, 3.08]
            
#Host 1 to Router
ds_ip6_hr = [0.972, 0.970, 0.940, 1.01, 0.994, 1.08, 1.21, 1.05, 1.06, 1.08, 1.01, 1.00, 0.985, 1.02, 0.996, 1.02, 1.01, 0.982, 1.03, 1.00, 0.981, 0.999, 0.962, 
             0.998, 0.975, 0.989, 1.10, 0.973, 1.07, 0.974, 0.974, 1.01, 0.964, 1.02, 0.987, 0.985, 0.961, 0.929, 0.989, 0.990, 0.959, 1.03, 1.04, 1.04, 1.02, 
             1.03, 0.986, 0.944, 0.996, 0.955, 1.02, 0.970, 1.01, 0.988, 0.943, 0.938, 0.959, 0.947, 1.02, 0.952, 0.938, 0.973, 0.933, 0.956, 0.908, 0.948, 0.962, 
             0.956, 1.08, 0.956, 0.949, 1.01, 0.950, 0.983, 0.947, 0.977, 0.953, 1.05, 1.18, 1.08, 1.11, 1.27, 1.02, 1.04, 0.987, 0.971, 0.960, 0.982, 1.05, 1.06, 
             0.934, 1.03, 0.955, 1.00, 0.956, 0.965, 0.958, 0.952, 1.03, 0.987, 1.00, 0.994, 0.951, 0.993, 0.979, 0.995, 1.03, 0.986, 1.09, 0.971, 1.04, 1.46, 0.979, 
             1.03, 1.05, 1.06, 1.06, 1.11, 1.05, 0.981, 0.972, 0.978, 0.986, 1.02, 0.996, 1.01, 1.03, 0.987, 1.03, 1.02, 0.974, 1.18, 0.963, 0.997, 0.988, 0.999, 
             1.17, 1.08, 1.02, 0.965, 0.996, 0.951, 0.925, 1.07, 0.995, 0.966, 0.992, 0.931, 1.01, 0.957, 1.04, 1.04, 1.17, 1.03, 1.03, 1.03, 0.974, 0.952, 1.04, 
             1.01, 0.965, 0.976, 0.943, 0.969, 0.993, 0.938, 0.992, 0.969, 0.994, 0.895, 0.942, 0.982, 0.946, 1.07, 0.968, 0.955, 0.954, 0.936, 1.03, 0.972, 0.967, 
             0.964, 0.982, 0.993, 1.01, 1.00, 1.10, 1.06, 1.07, 1.20, 1.06, 1.03, 0.973, 1.00, 0.981, 1.05, 1.01, 0.962, 1.02, 0.984, 0.965, 1.05, 0.986, 1.01, 0.971, 
             0.988, 1.02, 0.963, 1.01, 0.992, 1.03, 1.01, 1.01, 0.996, 0.988, 1.00, 1.04, 0.995, 1.06, 1.03, 1.02, 1.01, 1.12, 1.18, 1.12, 1.08, 1.08, 1.09, 1.03, 
             0.907, 0.947, 0.945, 0.938, 0.964, 0.949, 0.954, 1.05, 0.925, 1.03, 1.00, 0.963, 0.938, 0.976, 0.957, 0.952, 0.946, 0.972, 1.00, 0.978, 0.936]
ds_ip6_hr_cc = [2.02, 1.95, 1.87, 1.81, 1.78,
                1.74, 1.96, 1.79, 1.88, 1.78, 
                1.74, 1.78, 1.77, 1.90, 1.76,
                1.72, 1.74, 1.78, 1.78, 1.84,
                1.79, 1.81, 1.78, 1.89, 1.76]

# %%
r4_ip4_hh_mean = round(np.mean(r4_ip4_hh), 3)
r4_ip4_hh_std_dev = round(np.std(r4_ip4_hh), 3)
print("R4 IP4 HH Mean:", r4_ip4_hh_mean)
print("R4 IP4 HH Two Standard Deviations:", r4_ip4_hh_std_dev*2)

r6_ip6_hh_mean = round(np.mean(r6_ip6_hh), 3)
r6_ip6_hh_std_dev = round(np.std(r6_ip6_hh), 3)
print("R6 IP6 HH Mean:", r6_ip6_hh_mean)
print("R6 IP6 HH Two Standard Deviations:", r6_ip6_hh_std_dev*2)

ds_ip4_hh_mean = round(np.mean(ds_ip4_hh), 3)
ds_ip4_hh_std_dev = round(np.std(ds_ip4_hh), 3)
print("DS IP4 HH Mean:", ds_ip4_hh_mean)
print("DS IP4 HH Two Standard Deviations:", ds_ip4_hh_std_dev*2)

ds_ip6_hh_mean = round(np.mean(ds_ip6_hh), 3)
ds_ip6_hh_std_dev = round(np.std(ds_ip6_hh), 3)
print("DS IP6 HH Mean:", ds_ip6_hh_mean)
print("DS IP6 HH Two Standard Deviations:", ds_ip6_hh_std_dev*2)


r4_ip4_hr_mean = round(np.mean(r4_ip4_hr), 3)
r4_ip4_hr_std_dev = round(np.std(r4_ip4_hr), 3)
print("R4 IP4 HR Mean:", r4_ip4_hr_mean)
print("R4 IP4 HR Two Standard Deviations:", r4_ip4_hr_std_dev*2)

r6_ip6_hr_mean = round(np.mean(r6_ip6_hr), 3)
r6_ip6_hr_std_dev = round(np.std(r6_ip6_hr), 3)
print("R6 IP6 HR Mean:", r6_ip6_hr_mean)
print("R6 IP6 HR Two Standard Deviations:", r6_ip6_hr_std_dev*2)

ds_ip4_hr_mean = round(np.mean(ds_ip4_hr), 3)
ds_ip4_hr_std_dev = round(np.std(ds_ip4_hr), 3)
print("DS IP4 HR Mean:", ds_ip4_hr_mean)
print("DS IP4 HR Two Standard Deviations:", ds_ip4_hr_std_dev*2)

ds_ip6_hr_mean = round(np.mean(ds_ip6_hr), 3)
ds_ip6_hr_std_dev = round(np.std(ds_ip6_hr), 3)
print("DS IP6 HR Mean:", ds_ip6_hr_mean)
print("DS IP6 HR Two Standard Deviations:", ds_ip6_hr_std_dev*2)
# Out:
# R4 IP4 HH Mean: 1.473
# R4 IP4 HH Two Standard Deviations: 0.128
# R6 IP6 HH Mean: 1.555
# R6 IP6 HH Two Standard Deviations: 0.128
# DS IP4 HH Mean: 1.531
# DS IP4 HH Two Standard Deviations: 0.122
# DS IP6 HH Mean: 1.602
# DS IP6 HH Two Standard Deviations: 0.15
# R4 IP4 HR Mean: 0.971
# R4 IP4 HR Two Standard Deviations: 0.128
# R6 IP6 HR Mean: 0.964
# R6 IP6 HR Two Standard Deviations: 0.094
# DS IP4 HR Mean: 0.994
# DS IP4 HR Two Standard Deviations: 0.108
# DS IP6 HR Mean: 1.004
# DS IP6 HR Two Standard Deviations: 0.124

# %%
r4_ip4_hh_cc_mean = round(np.mean(r4_ip4_hh_cc), 3)
r4_ip4_hh_cc_std_dev = round(np.std(r4_ip4_hh_cc), 3)
print("R4 IP4 HH CC Mean:", r4_ip4_hh_cc_mean)
print("R4 IP4 HH CC Two Standard Deviations:", r4_ip4_hh_cc_std_dev*2)

r6_ip6_hh_cc_mean = round(np.mean(r6_ip6_hh_cc), 3)
r6_ip6_hh_cc_std_dev = round(np.std(r6_ip6_hh_cc), 3)
print("R6 IP6 HH CC Mean:", r6_ip6_hh_cc_mean)
print("R6 IP6 HH CC Two Standard Deviations:", r6_ip6_hh_cc_std_dev*2)

ds_ip4_hh_cc_mean = round(np.mean(ds_ip4_hh_cc), 3)
ds_ip4_hh_cc_std_dev = round(np.std(ds_ip4_hh_cc), 3)
print("DS IP4 HH CC Mean:", ds_ip4_hh_cc_mean)
print("DS IP4 HH CC Two Standard Deviations:", ds_ip4_hh_cc_std_dev*2)

ds_ip6_hh_cc_mean = round(np.mean(ds_ip6_hh_cc), 3)
ds_ip6_hh_cc_std_dev = round(np.std(ds_ip6_hh_cc), 3)
print("DS IP6 HH CC Mean:", ds_ip6_hh_cc_mean)
print("DS IP6 HH CC Two Standard Deviations:", ds_ip6_hh_cc_std_dev*2)

r4_ip4_hr_cc_mean = round(np.mean(r4_ip4_hr_cc), 3)
r4_ip4_hr_cc_std_dev = round(np.std(r4_ip4_hr_cc), 3)
print("R4 IP4 HR CC Mean:", r4_ip4_hr_cc_mean)
print("R4 IP4 HR CC Two Standard Deviations:", r4_ip4_hr_cc_std_dev*2)

r6_ip6_hr_cc_mean = round(np.mean(r6_ip6_hr_cc), 3)
r6_ip6_hr_cc_std_dev = round(np.std(r6_ip6_hr_cc), 3)
print("R6 IP6 HR CC Mean:", r6_ip6_hr_cc_mean)
print("R6 IP6 HR CC Two Standard Deviations:", r6_ip6_hr_cc_std_dev*2)

ds_ip4_hr_cc_mean = round(np.mean(ds_ip4_hr_cc), 3)
ds_ip4_hr_cc_std_dev = round(np.std(ds_ip4_hr_cc), 3)
print("DS IP4 HR CC Mean:", ds_ip4_hr_cc_mean)
print("DS IP4 HR CC Two Standard Deviations:", ds_ip4_hr_cc_std_dev*2)

ds_ip6_hr_cc_mean = round(np.mean(ds_ip6_hr_cc), 3)
ds_ip6_hr_cc_std_dev = round(np.std(ds_ip6_hr_cc), 3)
print("DS IP6 HR CC Mean:", ds_ip6_hr_cc_mean)
print("DS IP6 HR CC Two Standard Deviations:", ds_ip6_hr_cc_std_dev*2)
# Out:
# R4 IP4 HH CC Mean: 2.77
# R4 IP4 HH CC Two Standard Deviations: 0.202
# R6 IP6 HH CC Mean: 3.235
# R6 IP6 HH CC Two Standard Deviations: 0.19
# DS IP4 HH CC Mean: 2.864
# DS IP4 HH CC Two Standard Deviations: 0.28
# DS IP6 HH CC Mean: 3.262
# DS IP6 HH CC Two Standard Deviations: 0.24
# R4 IP4 HR CC Mean: 1.596
# R4 IP4 HR CC Two Standard Deviations: 0.244
# R6 IP6 HR CC Mean: 1.746
# R6 IP6 HR CC Two Standard Deviations: 0.146
# DS IP4 HR CC Mean: 1.748
# DS IP4 HR CC Two Standard Deviations: 0.32
# DS IP6 HR CC Mean: 1.817
# DS IP6 HR CC Two Standard Deviations: 0.152

# %%
r4_ip4_hh_sorted = np.sort(r4_ip4_hh)
r6_ip6_hh_sorted = np.sort(r6_ip6_hh)
ds_ip4_hh_sorted = np.sort(ds_ip4_hh)
ds_ip6_hh_sorted = np.sort(ds_ip6_hh)

r4_ip4_hh_cdf = np.arange(len(r4_ip4_hh_sorted)) / float(len(r4_ip4_hh_sorted))
r6_ip6_hh_cdf = np.arange(len(r6_ip6_hh_sorted)) / float(len(r6_ip6_hh_sorted))
ds_ip4_hh_cdf = np.arange(len(ds_ip4_hh_sorted)) / float(len(ds_ip4_hh_sorted))
ds_ip6_hh_cdf = np.arange(len(ds_ip6_hh_sorted)) / float(len(ds_ip6_hh_sorted))

r4_ip4_hr_sorted = np.sort(r4_ip4_hr)
r6_ip6_hr_sorted = np.sort(r6_ip6_hr)
ds_ip4_hr_sorted = np.sort(ds_ip4_hr)
ds_ip6_hr_sorted = np.sort(ds_ip6_hr)

r4_ip4_hr_cdf = np.arange(len(r4_ip4_hr_sorted)) / float(len(r4_ip4_hr_sorted))
r6_ip6_hr_cdf = np.arange(len(r6_ip6_hr_sorted)) / float(len(r6_ip6_hr_sorted))
ds_ip4_hr_cdf = np.arange(len(ds_ip4_hr_sorted)) / float(len(ds_ip4_hr_sorted))
ds_ip6_hr_cdf = np.arange(len(ds_ip6_hr_sorted)) / float(len(ds_ip6_hr_sorted))

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

axs[0].plot(r4_ip4_hh_sorted, r4_ip4_hh_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[0].plot(r6_ip6_hh_sorted, r6_ip6_hh_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[0].plot(ds_ip4_hh_sorted, ds_ip4_hh_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[0].plot(ds_ip6_hh_sorted, ds_ip6_hh_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[0].grid(True)
axs[0].set_title('Warm Cache Host-to-Host ping RTT (ms)')
axs[0].set_xlabel('Time (ms)')
axs[0].set_ylabel('Cumulative Probability')
axs[0].legend()

axs[1].plot(r4_ip4_hr_sorted, r4_ip4_hr_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[1].plot(r6_ip6_hr_sorted, r6_ip6_hr_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[1].plot(ds_ip4_hr_sorted, ds_ip4_hr_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[1].plot(ds_ip6_hr_sorted, ds_ip6_hr_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[1].grid(True)
axs[1].set_title('Warm Cache Host-to-Router ping RTT (ms)')
axs[1].set_xlabel('Time (ms)')
axs[1].set_ylabel('Cumulative Probability')
axs[1].legend()

plt.savefig('Ping_WC.png')
plt.show()

# %%
r4_ip4_hh_cc_sorted = np.sort(r4_ip4_hh_cc)
r6_ip6_hh_cc_sorted = np.sort(r6_ip6_hh_cc)
ds_ip4_hh_cc_sorted = np.sort(ds_ip4_hh_cc)
ds_ip6_hh_cc_sorted = np.sort(ds_ip6_hh_cc)

r4_ip4_hh_cc_cdf = np.arange(len(r4_ip4_hh_cc_sorted)) / float(len(r4_ip4_hh_cc_sorted))
r6_ip6_hh_cc_cdf = np.arange(len(r6_ip6_hh_cc_sorted)) / float(len(r6_ip6_hh_cc_sorted))
ds_ip4_hh_cc_cdf = np.arange(len(ds_ip4_hh_cc_sorted)) / float(len(ds_ip4_hh_cc_sorted))
ds_ip6_hh_cc_cdf = np.arange(len(ds_ip6_hh_cc_sorted)) / float(len(ds_ip6_hh_cc_sorted))

r4_ip4_hr_cc_sorted = np.sort(r4_ip4_hr_cc)
r6_ip6_hr_cc_sorted = np.sort(r6_ip6_hr_cc)
ds_ip4_hr_cc_sorted = np.sort(ds_ip4_hr_cc)
ds_ip6_hr_cc_sorted = np.sort(ds_ip6_hr_cc)

r4_ip4_hr_cc_cdf = np.arange(len(r4_ip4_hr_cc_sorted)) / float(len(r4_ip4_hr_cc_sorted))
r6_ip6_hr_cc_cdf = np.arange(len(r6_ip6_hr_cc_sorted)) / float(len(r6_ip6_hr_cc_sorted))
ds_ip4_hr_cc_cdf = np.arange(len(ds_ip4_hr_cc_sorted)) / float(len(ds_ip4_hr_cc_sorted))
ds_ip6_hr_cc_cdf = np.arange(len(ds_ip6_hr_cc_sorted)) / float(len(ds_ip6_hr_cc_sorted))

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

axs[0].plot(r4_ip4_hh_cc_sorted, r4_ip4_hh_cc_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[0].plot(r6_ip6_hh_cc_sorted, r6_ip6_hh_cc_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[0].plot(ds_ip4_hh_cc_sorted, ds_ip4_hh_cc_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[0].plot(ds_ip6_hh_cc_sorted, ds_ip6_hh_cc_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[0].grid(True)
axs[0].set_title('Cold Cache Host-to-Host Ping RTT (ms)')
axs[0].set_xlabel('Time (ms)')
axs[0].set_ylabel('Cumulative Probability')
axs[0].legend()

axs[1].plot(r4_ip4_hr_cc_sorted, r4_ip4_hr_cc_cdf, label='IPv4 Router', color='green', linestyle='dotted')
axs[1].plot(r6_ip6_hr_cc_sorted, r6_ip6_hr_cc_cdf, label='IPv6 Router', color='blue', linestyle='dashed')
axs[1].plot(ds_ip4_hr_cc_sorted, ds_ip4_hr_cc_cdf, label='Dual-stack IPv4', color='black', linestyle='dashdot')
axs[1].plot(ds_ip6_hr_cc_sorted, ds_ip6_hr_cc_cdf, label='Dual-stack IPv6', color='red', linestyle='solid')
axs[1].grid(True)
axs[1].set_title('Cold Cache Host-to-Router Ping RTT (ms)')
axs[1].set_xlabel('Time (ms)')
axs[1].set_ylabel('Cumulative Probability')
axs[1].legend()

plt.savefig('Ping_CC.png')
plt.show()
